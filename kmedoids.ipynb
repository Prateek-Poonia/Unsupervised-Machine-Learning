# %% [markdown]
# <a href="https://colab.research.google.com/github/Prateek-Poonia/Unsupervised-Machine-Learning/blob/main/kmedoids.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn-extra
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn_extra.cluster import KMedoids # Changed sklearn.extra to sklearn_extra
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.9 MB/s eta 0:00:00
# ...

# %%
X,y = make_blobs(n_samples=300,centers = 4, random_state = 42)

#apply k medoids algorithm
kmedoids = KMedoids(n_clusters=4, random_state=42)
kmedoids.fit(X)

#get the medoids and labels
medoids = kmedoids.cluster_centers_
labels = kmedoids.labels_

# %%
# Plot the results
plt.figure(figsize=(10, 6))

# Plot each cluster
for i in range(4):
    plt.scatter(X[labels == i, 0], X[labels == i, 1], label=f'Cluster {i}')

# Plot the medoids
plt.scatter(medoids[:, 0], medoids[:, 1], c='red', marker='X', s=200, label='Medoids')

plt.title('K-Medoids Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
